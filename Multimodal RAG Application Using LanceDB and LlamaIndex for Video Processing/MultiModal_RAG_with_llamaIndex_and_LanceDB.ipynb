# %%
from moviepy.editor import VideoFileClip
from pathlib import Path
import speech_recognition as sr
from pytube import YouTube
from pprint import pprint
from PIL import Image
import matplotlib.pyplot as plt

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
os.getcwd()
# Out:
# 'c:\\Users\\vikas\\OneDrive\\Desktop\\Generative-AI-Sunny-Sir\\Multimodal RAG Application Using LanceDB and LlamaIndex for Video Processing'

# %%
video_url="https://www.youtube.com/watch?v=EKm0spFxFG4"

# %%
output_video_path = "/mixed_data/video_data/"

# %%
# from the video i am going to collect images,audio,text
output_folder = "/mixed_data/"
output_audio_path = "/mixed_data/audio_output/output_audio.wav"

# %%
output_audio_path
# Out:
# '/mixed_data/audio_output/output_audio.wav'

# %%
# !mkdir mixed_data
# Out:
# A subdirectory or file mixed_data already exists.

# %%
filepath = output_video_path + "input_vid.mp4"
print(filepath)
# Out:
# /content/video_data/input_vid.mp4

# %%
import yt_dlp

def download_video(url, output_path):
    ydl_opts = {
        'format': 'best',
        'outtmpl': f"{output_path}/input_vid.mp4"
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)
        metadata = {"Author": info.get("uploader"), "Title": info.get("title"), "Views": info.get("view_count")}
    return metadata

video_url = "https://www.youtube.com/watch?v=EKm0spFxFG4"
output_video_path = "/content/video_data/"
metadata_vid = download_video(video_url, output_video_path)
print(metadata_vid)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EKm0spFxFG4
# [youtube] EKm0spFxFG4: Downloading webpage
# [youtube] EKm0spFxFG4: Downloading tv client config
# [youtube] EKm0spFxFG4: Downloading player 91201489
# [youtube] EKm0spFxFG4: Downloading tv player API JSON
# [youtube] EKm0spFxFG4: Downloading ios player API JSON
# [youtube] EKm0spFxFG4: Downloading m3u8 information
# [info] EKm0spFxFG4: Downloading 1 format(s): 18
# [download] \content\video_data\input_vid.mp4 has already been downloaded
# [download] 100% of    5.28MiB
# {'Author': '3-Minute Data Science', 'Title': 'Logistic Regression in 3 Minutes', 'Views': 124671}

# %%
from moviepy.editor import VideoFileClip
def video_to_images(video_path,output_folder):
  clip=VideoFileClip(video_path)
  clip.write_images_sequence(
      os.path.join(output_folder,"frame%04d.png"),fps=0.2
  )

# %%
def video_to_audio(video_path,output_audio_path):
  clip=VideoFileClip(video_path)
  audio=clip.audio
  audio.write_audiofile(output_audio_path)

# %%
def audio_to_text(audio_path):
  recognizer=sr.Recognizer()
  audio=sr.AudioFile(audio_path)

  with audio as source:
    audio_data=recognizer.record(source)

    try:

      #recognize the speech
      text = recognizer.recognize_whisper(audio_data)

    except sr.UnknownValueError:
      print("Speech recognition could not understand the audio.")
  return text

# %%
video_url
# Out:
# 'https://www.youtube.com/watch?v=EKm0spFxFG4'

# %%
output_video_path
# Out:
# '/content/video_data/'

# %%
metadata_vid = download_video(video_url, output_video_path)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EKm0spFxFG4
# [youtube] EKm0spFxFG4: Downloading webpage
# [youtube] EKm0spFxFG4: Downloading tv client config
# [youtube] EKm0spFxFG4: Downloading player 91201489
# [youtube] EKm0spFxFG4: Downloading tv player API JSON
# [youtube] EKm0spFxFG4: Downloading ios player API JSON
# [youtube] EKm0spFxFG4: Downloading m3u8 information
# [info] EKm0spFxFG4: Downloading 1 format(s): 18
# [download] \content\video_data\input_vid.mp4 has already been downloaded
# [download] 100% of    5.28MiB

# %%
metadata_vid
# Out:
# {'Author': '3-Minute Data Science',
#  'Title': 'Logistic Regression in 3 Minutes',
#  'Views': 124671}

# %%
filepath
# Out:
# '/content/video_data/input_vid.mp4'

# %%
video_to_images(filepath,output_folder)
# Out:
# t:   0%|          | 0/46 [00:00<?, ?it/s, now=None]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 video_to_images(filepath,output_folder)
#
# Cell In[12], line 4, in video_to_images(video_path, output_folder)
#       2 def video_to_images(video_path,output_folder):
#       3   clip=VideoFileClip(video_path)
# ----> 4   clip.write_images_sequence(
#       5       os.path.join(output_folder,"frame%04d.png"),fps=0.2
#       6   )
#
# File <decorator-gen-81>:2, in write_images_sequence(self, nameformat, fps, withmask, logger)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\moviepy\decorators.py:56, in requires_duration(f, clip, *a, **k)
#      54     raise ValueError("Attribute 'duration' not set")
#      55 else:
# ---> 56     return f(clip, *a, **k)
#
# File <decorator-gen-80>:2, in write_images_sequence(self, nameformat, fps, withmask, logger)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\moviepy\decorators.py:135, in use_clip_fps_by_default(f, clip, *a, **k)
#     132 new_a = [fun(arg) if (name == "fps") else arg for (arg, name) in zip(a, names)]
#     133 new_kw = {k: fun(v) if k == "fps" else v for (k, v) in k.items()}
# --> 135 return f(clip, *new_a, **new_kw)
#
# File <decorator-gen-79>:2, in write_images_sequence(self, nameformat, fps, withmask, logger)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\moviepy\decorators.py:24, in convert_masks_to_RGB(f, clip, *a, **k)
#      22 if clip.ismask:
#      23     clip = clip.to_RGB()
# ---> 24 return f(clip, *a, **k)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\moviepy\video\VideoClip.py:413, in VideoClip.write_images_sequence(self, nameformat, fps, withmask, logger)
#     411     name = nameformat % i
#     412     filenames.append(name)
# --> 413     self.save_frame(name, t, withmask=withmask)
#     414 # logger(message="Moviepy - Done writing frames %s." % nameformat)
#     416 return filenames
#
# File <decorator-gen-73>:2, in save_frame(self, filename, t, withmask)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      84 new_a = [
#      85     fun(arg) if (name in varnames) and (arg is not None) else arg
#      86     for (arg, name) in zip(a, names)
#      87 ]
#      88 new_kw = {k: fun(v) if k in varnames else v for (k, v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File <decorator-gen-72>:2, in save_frame(self, filename, t, withmask)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\moviepy\decorators.py:24, in convert_masks_to_RGB(f, clip, *a, **k)
#      22 if clip.ismask:
#      23     clip = clip.to_RGB()
# ---> 24 return f(clip, *a, **k)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\moviepy\video\VideoClip.py:144, in VideoClip.save_frame(self, filename, t, withmask)
#     141 else:
#     142     im = im.astype("uint8")
# --> 144 imsave(filename, im)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\imageio\v2.py:396, in imwrite(uri, im, format, **kwargs)
#     394 imopen_args = decypher_format_arg(format)
#     395 imopen_args["legacy_mode"] = True
# --> 396 with imopen(uri, "wi", **imopen_args) as file:
#     397     return file.write(im, **kwargs)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\imageio\core\request.py:249, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     246     raise ValueError(f"Invalid Request.Mode: {mode}")
#     248 # Parse what was given
# --> 249 self._parse_uri(uri)
#     251 # Set extension
#     252 if extension is not None:
#
# File c:\Users\vikas\OneDrive\Desktop\Generative-AI-Sunny-Sir\genai\lib\site-packages\imageio\core\request.py:414, in Request._parse_uri(self, uri)
#     412 dn = os.path.dirname(fn)
#     413 if not os.path.exists(dn):
# --> 414     raise FileNotFoundError("The directory %r does not exist" % dn)
#
# FileNotFoundError: The directory 'c:\\mixed_data' does not exist

# %% [markdown]
# ---

# %% [markdown]
# ---
